# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
derecho = pd.read_csv('derecho.csv')
izquierdo = pd.read_csv('izquierdo.csv') 

test = pd.read_csv('data_test_Mariano_Rubiolo_RAW_AF7_RAW_AF8.csv.csv')

# %%
raw_af7_ambos= ambos['RAW_AF7']
raw_af8_ambos = ambos['RAW_AF8']
   
raw_af7_izq = izquierdo['RAW_AF7']
raw_af8_izq = izquierdo['RAW_AF8']

raw_af7_der = derecho['RAW_AF7']
raw_af8_der = derecho['RAW_AF8']

raw_af7_test = test['RAW_AF7']
raw_af8_test = test['RAW_AF8']

# %%
for i in range(len(raw_af7_ambos)):
    if np.isnan(raw_af7_ambos[i]):
        raw_af7_ambos[i]=raw_af7_ambos[i-1]
    if np.isnan(raw_af8_ambos[i]):
        raw_af8_ambos[i]=raw_af8_ambos[i-1]

for i in range(len(raw_af7_der)):
    if np.isnan(raw_af7_der[i]):
        raw_af7_der[i]=raw_af7_der[i-1]
    if np.isnan(raw_af8_der[i]):
        raw_af8_der[i]=raw_af8_der[i-1]

for i in range(len(raw_af7_izq)):
    if np.isnan(raw_af7_izq[i]):
        raw_af7_izq[i]=raw_af7_izq[i-1]
    if np.isnan(raw_af8_izq[i]):
        raw_af8_izq[i]=raw_af8_izq[i-1]
    
for i in range(len(raw_af7_test)):
    if np.isnan(raw_af7_test[i]):
        raw_af7_test[i]=raw_af7_test[i-1]
    if np.isnan(raw_af8_test[i]):
        raw_af8_test[i]=raw_af8_test[i-1]
# Out:
# c:\users\matias tibaldo\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\users\matias tibaldo\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# c:\users\matias tibaldo\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
from pandas import DataFrame

ambos_RAW_AF7_RAW_AF8 = {'RAW_AF7':raw_af7_ambos,
                         'RAW_AF8':raw_af8_ambos
          }


izquierdo_RAW_AF7_RAW_AF8 = {'RAW_AF7':raw_af7_izq,
                             'RAW_AF8':raw_af8_izq
          }

derecho_RAW_AF7_RAW_AF8 = {'RAW_AF7':raw_af7_der,
                           'RAW_AF8':raw_af8_der
          }

test_RAW_AF7_RAW_AF8 = {'RAW_AF7':raw_af7_test,
                        'RAW_AF8':raw_af8_test
          }

am = DataFrame(ambos_RAW_AF7_RAW_AF8, columns= ['RAW_AF7', 'RAW_AF8'])

izq = DataFrame(izquierdo_RAW_AF7_RAW_AF8, columns= ['RAW_AF7', 'RAW_AF8'])

der = DataFrame(derecho_RAW_AF7_RAW_AF8, columns= ['RAW_AF7', 'RAW_AF8'])

test = DataFrame(test_RAW_AF7_RAW_AF8, columns= ['RAW_AF7', 'RAW_AF8'])

export_csv = am.to_csv (r'ambos_RAW_AF7_RAW_AF8.csv')

export_csv_izq = izq.to_csv (r'izquierdo_RAW_AF7_RAW_AF8.csv')

export_csv_der = der.to_csv (r'derecho_RAW_AF7_RAW_AF8.csv') 

export_csv_test = test.to_csv(r'test_RAW_AF7_RAW_AF8.csv')

#export_csv_test =  df_test.to_csv(r'salidas_test.csv', index=None, header=True)
#print (df)

# %%
from google.colab import files

files.download('salida.csv')

#files.download('salidas_test.csv')

# %%
Alpha_AF7 = (r1['Alpha_AF7'][0:8000], r2['Alpha_AF7'][0:8000],r3['Alpha_AF7'][0:8000],r4['Alpha_AF7'][0:8000],r5['Alpha_AF7'][0:8000],v1['Alpha_AF7'][0:8000], v2['Alpha_AF7'][0:8000],v3['Alpha_AF7'][0:8000],v4['Alpha_AF7'][0:8000],v5['Alpha_AF7'][0:8000])
Alpha_AF8 = (r1['Alpha_AF8'][0:8000], r2['Alpha_AF8'][0:8000],r3['Alpha_AF8'][0:8000],r4['Alpha_AF8'][0:8000],r5['Alpha_AF8'][0:8000],v1['Alpha_AF8'][0:8000], v2['Alpha_AF8'][0:8000],v3['Alpha_AF8'][0:8000],v4['Alpha_AF8'][0:8000],v5['Alpha_AF8'][0:8000])
Beta_AF7 = (r1['Beta_AF7'][0:8000], r2['Beta_AF7'][0:8000],r3['Beta_AF7'][0:8000],r4['Beta_AF7'][0:8000],r5['Beta_AF7'][0:8000],v1['Beta_AF7'][0:8000], v2['Beta_AF7'][0:8000],v3['Beta_AF7'][0:8000],v4['Beta_AF7'][0:8000],v5['Beta_AF7'][0:8000])
Beta_AF8 = (r1['Beta_AF8'][0:8000], r2['Beta_AF8'][0:8000],r3['Beta_AF8'][0:8000],r4['Beta_AF8'][0:8000],r5['Beta_AF8'][0:8000],v1['Beta_AF8'][0:8000], v2['Beta_AF8'][0:8000],v3['Beta_AF8'][0:8000],v4['Beta_AF8'][0:8000],v5['Beta_AF8'][0:8000])
Gamma_AF7 = (r1['Gamma_AF7'][0:8000], r2['Gamma_AF7'][0:8000],r3['Gamma_AF7'][0:8000],r4['Gamma_AF7'][0:8000],r5['Gamma_AF7'][0:8000],v1['Gamma_AF7'][0:8000], v2['Gamma_AF7'][0:8000],v3['Gamma_AF7'][0:8000],v4['Gamma_AF7'][0:8000],v5['Gamma_AF7'][0:8000])
Gamma_AF8 = (r1['Gamma_AF8'][0:8000], r2['Gamma_AF8'][0:8000],r3['Gamma_AF8'][0:8000],r4['Gamma_AF8'][0:8000],r5['Gamma_AF8'][0:8000],v1['Gamma_AF8'][0:8000], v2['Gamma_AF8'][0:8000],v3['Gamma_AF8'][0:8000],v4['Gamma_AF8'][0:8000],v5['Gamma_AF8'][0:8000])


Alpha_AF7_test = test_roja['Alpha_AF7'][0:8000],test_verde['Alpha_AF7'][0:8000]
Alpha_AF8_test = test_roja['Alpha_AF8'][0:8000],test_verde['Alpha_AF8'][0:8000]
Beta_AF7_test = test_roja['Beta_AF7'][0:8000],test_verde['Beta_AF7'][0:8000]
Beta_AF8_test = test_roja['Beta_AF8'][0:8000],test_verde['Beta_AF8'][0:8000]
Gamma_AF7_test = test_roja['Gamma_AF7'][0:8000],test_verde['Gamma_AF7'][0:8000]
Gamma_AF8_test = test_roja['Gamma_AF8'][0:8000],test_verde['Gamma_AF8'][0:8000]

Alpha_AF7_test_2 = test_roja_2['Alpha_AF7'][0:8000],test_verde_2['Alpha_AF7'][0:8000]
Alpha_AF8_test_2 = test_roja_2['Alpha_AF8'][0:8000],test_verde_2['Alpha_AF8'][0:8000]
Beta_AF7_test_2 = test_roja_2['Beta_AF7'][0:8000],test_verde_2['Beta_AF7'][0:8000]
Beta_AF8_test_2 = test_roja_2['Beta_AF8'][0:8000],test_verde_2['Beta_AF8'][0:8000]
Gamma_AF7_test_2 = test_roja_2['Gamma_AF7'][0:8000],test_verde_2['Gamma_AF7'][0:8000]
Gamma_AF8_test_2 = test_roja_2['Gamma_AF8'][0:8000],test_verde_2['Gamma_AF8'][0:8000]

# %%
alpha_AF7 = np.zeros(80000)
alpha_AF8 = np.zeros(80000)
beta_AF7 = np.zeros(80000)
beta_AF8 = np.zeros(80000)
gamma_AF7 = np.zeros(80000)
gamma_AF8 = np.zeros(80000)

for i in range(0,8000):
  alpha_AF7[i]=Alpha_AF7[0][i]
  alpha_AF7[i+8000]=Alpha_AF7[1][i]
  alpha_AF7[i+16000]=Alpha_AF7[2][i]
  alpha_AF7[i+24000]=Alpha_AF7[3][i]
  alpha_AF7[i+32000]=Alpha_AF7[4][i]
  alpha_AF7[i+40000]=Alpha_AF7[5][i]
  alpha_AF7[i+48000]=Alpha_AF7[6][i]
  alpha_AF7[i+56000]=Alpha_AF7[7][i]
  alpha_AF7[i+64000]=Alpha_AF7[8][i]
  alpha_AF7[i+72000]=Alpha_AF7[9][i]

  
  alpha_AF8[i]=Alpha_AF8[0][i]
  alpha_AF8[i+8000]=Alpha_AF8[1][i]
  alpha_AF8[i+16000]=Alpha_AF8[2][i]
  alpha_AF8[i+24000]=Alpha_AF8[3][i]
  alpha_AF8[i+32000]=Alpha_AF8[4][i]
  alpha_AF8[i+40000]=Alpha_AF8[5][i]
  alpha_AF8[i+48000]=Alpha_AF8[6][i]
  alpha_AF8[i+56000]=Alpha_AF8[7][i]
  alpha_AF8[i+64000]=Alpha_AF8[8][i]
  alpha_AF8[i+72000]=Alpha_AF8[9][i]
  
  beta_AF7[i]=Beta_AF7[0][i]
  beta_AF7[i+8000]=Beta_AF7[1][i]
  beta_AF7[i+16000]=Beta_AF7[2][i]
  beta_AF7[i+24000]=Beta_AF7[3][i]
  beta_AF7[i+32000]=Beta_AF7[4][i]
  beta_AF7[i+40000]=Beta_AF7[5][i]
  beta_AF7[i+48000]=Beta_AF7[6][i]
  beta_AF7[i+56000]=Beta_AF7[7][i]
  beta_AF7[i+64000]=Beta_AF7[8][i]
  beta_AF7[i+72000]=Beta_AF7[9][i]

  
  beta_AF8[i]=Beta_AF8[0][i]
  beta_AF8[i+8000]=Beta_AF8[1][i]
  beta_AF8[i+16000]=Beta_AF8[2][i]
  beta_AF8[i+24000]=Beta_AF8[3][i]
  beta_AF8[i+32000]=Beta_AF8[4][i]
  beta_AF8[i+40000]=Beta_AF8[5][i]
  beta_AF8[i+48000]=Beta_AF8[6][i]
  beta_AF8[i+56000]=Beta_AF8[7][i]
  beta_AF8[i+64000]=Beta_AF8[8][i]
  beta_AF8[i+72000]=Beta_AF8[9][i]
  
    
  gamma_AF7[i]=Gamma_AF7[0][i]
  gamma_AF7[i+8000]=Gamma_AF7[1][i]
  gamma_AF7[i+16000]=Gamma_AF7[2][i]
  gamma_AF7[i+24000]=Gamma_AF7[3][i]
  gamma_AF7[i+32000]=Gamma_AF7[4][i]
  gamma_AF7[i+40000]=Gamma_AF7[5][i]
  gamma_AF7[i+48000]=Gamma_AF7[6][i]
  gamma_AF7[i+56000]=Gamma_AF7[7][i]
  gamma_AF7[i+64000]=Gamma_AF7[8][i]
  gamma_AF7[i+72000]=Gamma_AF7[9][i]

  
  gamma_AF8[i]=Gamma_AF8[0][i]
  gamma_AF8[i+8000]=Gamma_AF8[1][i]
  gamma_AF8[i+16000]=Gamma_AF8[2][i]
  gamma_AF8[i+24000]=Gamma_AF8[3][i]
  gamma_AF8[i+32000]=Gamma_AF8[4][i]
  gamma_AF8[i+40000]=Gamma_AF8[5][i]
  gamma_AF8[i+48000]=Gamma_AF8[6][i]
  gamma_AF8[i+56000]=Gamma_AF8[7][i]
  gamma_AF8[i+64000]=Gamma_AF8[8][i]
  gamma_AF8[i+72000]=Gamma_AF8[9][i]
  
alpha_AF7_test = np.zeros(16000)
alpha_AF8_test = np.zeros(16000) 
beta_AF7_test = np.zeros(16000)
beta_AF8_test = np.zeros(16000)
gamma_AF7_test = np.zeros(16000)
gamma_AF8_test = np.zeros(16000)

alpha_AF7_test_2 = np.zeros(16000)
alpha_AF8_test_2 = np.zeros(16000) 
beta_AF7_test_2 = np.zeros(16000)
beta_AF8_test_2 = np.zeros(16000)
gamma_AF7_test_2 = np.zeros(16000)
gamma_AF8_test_2 = np.zeros(16000)

for i in range(0,8000):
  alpha_AF7_test[i]=Alpha_AF7_test[0][i]
  alpha_AF7_test[i+8000]=Alpha_AF7_test[1][i]
  
  alpha_AF8_test[i]=Alpha_AF8_test[0][i]
  alpha_AF8_test[i+8000]=Alpha_AF8_test[1][i]

  beta_AF7_test[i]=Beta_AF7_test[0][i]
  beta_AF7_test[i+8000]=Beta_AF7_test[1][i]
  
  beta_AF8_test[i]=Beta_AF8_test[0][i]
  beta_AF8_test[i+8000]=Beta_AF8_test[1][i]
  
  gamma_AF7_test[i]=Gamma_AF7_test[0][i]
  gamma_AF7_test[i+8000]=Gamma_AF7_test[1][i]
  
  gamma_AF8_test[i]=Gamma_AF8_test[0][i]
  gamma_AF8_test[i+8000]=Gamma_AF8_test[1][i]
  
  
  alpha_AF7_test_2[i]=Alpha_AF7_test_2[0][i]
  alpha_AF7_test_2[i+8000]=Alpha_AF7_test_2[1][i]
  
  alpha_AF8_test_2[i]=Alpha_AF8_test_2[0][i]
  alpha_AF8_test_2[i+8000]=Alpha_AF8_test_2[1][i]

  beta_AF7_test_2[i]=Beta_AF7_test_2[0][i]
  beta_AF7_test_2[i+8000]=Beta_AF7_test_2[1][i]
  
  beta_AF8_test_2[i]=Beta_AF8_test_2[0][i]
  beta_AF8_test_2[i+8000]=Beta_AF8_test_2[1][i]
  gamma_AF7_test_2[i]=Gamma_AF7_test_2[0][i]
  gamma_AF7_test_2[i+8000]=Gamma_AF7_test_2[1][i]
  
  gamma_AF8_test_2[i]=Gamma_AF8_test_2[0][i]
  gamma_AF8_test_2[i+8000]=Gamma_AF8_test_2[1][i]

# %%
for i in range(0,80000):
  if np.isnan(alpha_AF7[i]):
    alpha_AF7[i]=alpha_AF7[i-1]
  if np.isnan(alpha_AF8[i]):
    alpha_AF8[i]=alpha_AF8[i-1]
  if np.isnan(beta_AF7[i]):
    beta_AF7[i]=beta_AF7[i-1]
  if np.isnan(beta_AF8[i]):
    beta_AF8[i]=beta_AF8[i-1]
  if np.isnan(gamma_AF7[i]):
    gamma_AF7[i]=gamma_AF7[i-1]
  if np.isnan(gamma_AF8[i]):
    gamma_AF8[i]=gamma_AF8[i-1]

for i in range (0,16000):
  if np.isnan(alpha_AF7_test[i]):
    alpha_AF7_test[i]=alpha_AF7_test[i-1]
  if np.isnan(alpha_AF8_test[i]):
    alpha_AF8_test[i]=alpha_AF8_test[i-1]  
  if np.isnan(beta_AF7_test[i]):
    beta_AF7_test[i]=beta_AF7_test[i-1]
  if np.isnan(beta_AF8_test[i]):
    beta_AF8_test[i]=beta_AF8_test[i-1]  
  if np.isnan(gamma_AF7_test[i]):
    gamma_AF7_test[i]=gamma_AF7_test[i-1]
  if np.isnan(gamma_AF8_test[i]):
    gamma_AF8_test[i]=gamma_AF8_test[i-1]  
  
  if np.isnan(alpha_AF7_test_2[i]):
    alpha_AF7_test_2[i]=alpha_AF7_test_2[i-1]
  if np.isnan(alpha_AF8_test_2[i]):
    alpha_AF8_test_2[i]=alpha_AF8_test_2[i-1]  
  if np.isnan(beta_AF7_test_2[i]):
    beta_AF7_test_2[i]=beta_AF7_test_2[i-1]
  if np.isnan(beta_AF8_test_2[i]):
    beta_AF8_test_2[i]=beta_AF8_test_2[i-1]
  if np.isnan(gamma_AF7_test_2[i]):
    gamma_AF7_test_2[i]=gamma_AF7_test_2[i-1]
  if np.isnan(gamma_AF8_test_2[i]):
    gamma_AF8_test_2[i]=gamma_AF8_test_2[i-1]

# %%
from pandas import DataFrame

salida = {'ALPHA_AF7':alpha_AF7,
          'ALPHA_AF8':alpha_AF8,
          'BETA_AF7':beta_AF7,
          'BETA_AF8':beta_AF8,
          'GAMMA_AF7':gamma_AF7,
          'GAMMA_AF8':gamma_AF8
          }

salida_test = {'ALPHA_AF7':alpha_AF7_test,
               'ALPHA_AF8':alpha_AF8_test,
               'BETA_AF7':beta_AF7_test,
               'BETA_AF8':beta_AF8_test,
               'GAMMA_AF7':gamma_AF7_test,
               'GAMMA_AF8':gamma_AF8_test
               }

salida_test_2 = {'ALPHA_AF7':alpha_AF7_test_2,
               'ALPHA_AF8':alpha_AF8_test_2,
               'BETA_AF7':beta_AF7_test_2,
               'BETA_AF8':beta_AF8_test_2,
               'GAMMA_AF7':gamma_AF7_test_2,
               'GAMMA_AF8':gamma_AF8_test_2
               }

df = DataFrame(salida, columns= ['ALPHA_AF7', 'ALPHA_AF8','BETA_AF7','BETA_AF8','GAMMA_AF7','GAMMA_AF8'])
df_test = DataFrame(salida_test, columns = ['ALPHA_AF7', 'ALPHA_AF8','BETA_AF7','BETA_AF8','GAMMA_AF7','GAMMA_AF8'])
df_test_2 = DataFrame(salida_test_2, columns = ['ALPHA_AF7', 'ALPHA_AF8','BETA_AF7','BETA_AF8','GAMMA_AF7','GAMMA_AF8'])


export_csv = df.to_csv (r'Alpha AF7-8 Beta AF7-8 Gamma AF7-8 fija-roja-verde.csv') #Don't forget to add '.csv' at the end of the path

export_csv_test =  df_test.to_csv(r'Alpha AF7-8 Beta AF7-8 Gamma AF7-8 fija-roja-verde test.csv', index=None, header=True)

export_csv_test_2 =  df_test_2.to_csv(r'Alpha AF7-8 Beta AF7-8 Gamma AF7-8 fija-roja-verde test 2.csv', index=None, header=True)

#print (df)

# %%
from google.colab import files

files.download('Alpha AF7-8 Beta AF7-8 roja-verde.csv')

files.download('Alpha AF7-8 Beta AF7-8 roja-verde test.csv')

files.download('Alpha AF7-8 Beta AF7-8 roja-verde test 2.csv')

# %%
i=32000
start = 0+i
end = 8000+i
start2 = 40000+i
end2 = 48000+i
plt.plot(alpha_AF7[start:end],alpha_AF8[start:end],'r*',alpha_AF7[start2:end2],alpha_AF8[start2:end2],'g*')

# %%
plt.plot(beta_AF7[start:end],beta_AF8[start:end],'r*', beta_AF7[start2:end2],beta_AF8[start2:end2],'g*')

# %%
a = 'Alpha_AF7'
b = 'Alpha_AF8'

plt.plot(test_roja_3[a],test_roja_3[b],'r*',test_verde_3[a],test_verde_3[b],'g*')

# %%
plt.plot(alpha_AF7_test[0:8000],alpha_AF8_test[0:8000],'r*',alpha_AF7_test[8000:16000],alpha_AF8_test[8000:16000],'g*')

# %%
plt.plot(beta_AF7_test[0:8000],beta_AF8_test[0:8000],'r',beta_AF7_test[8000:16000],beta_AF8_test[8000:16000],'g')

# %%
plt.plot(beta_AF7_test_2[0:8000],beta_AF8_test_2[0:8000],'r',beta_AF7_test_2[8000:16000],beta_AF8_test_2[8000:16000],'g')

# %%
plt.plot(alpha_AF7_test_2[0:8000],alpha_AF8_test_2[0:8000],'r',alpha_AF7_test_2[8000:16000],alpha_AF8_test_2[8000:16000],'g')

# %%
plt.plot(test_roja_2['Gamma_AF7'][0:8000],test_roja_2['Gamma_AF8'][0:8000],'r*',test_verde_2['Gamma_AF7'][0:8000],test_verde_2['Gamma_AF8'][0:8000],'g*')

# %%
#plt.plot(alpha_AF7)
plt.plot(alpha_AF8)
#plt.plot(beta_AF7)
plt.plot(beta_AF8)
